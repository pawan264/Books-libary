# %% [markdown]
# <a href="https://www.kaggle.com/code/pawangoswami/project1?scriptVersionId=117955279" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib as plt

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/ecommerce-purchases/Ecommerce Purchases

# %%
purchase = pd.read_csv('/kaggle/input/ecommerce-purchases/Ecommerce Purchases', index_col = 'Address')

# %%
purchase
# Out:
#                                                       Lot AM or PM  \
# Address
# 16629 Pace Camp Apt. 448\nAlexisborough, NE 771...  46 in       PM
# 9374 Jasmine Spurs Suite 508\nSouth John, TN 84...  28 rn       PM
# Unit 0065 Box 5052\nDPO AP 27450                    94 vE       PM
# 7780 Julia Fords\nNew Stacy, WA 45798               36 vm       PM
# 23012 Munoz Drive Suite 337\nNew Cynthia, TX 57826  20 IE       AM
# ...                                                   ...      ...
# 966 Castaneda Locks\nWest Juliafurt, CO 96415       92 XI       PM
# 832 Curtis Dam Suite 785\nNorth Edwardburgh, TX...  41 JY       AM
# Unit 4434 Box 6343\nDPO AE 28026-0283               74 Zh       AM
# 0096 English Rest\nRoystad, IA 12457                74 cL       PM
# 40674 Barrett Stravenue\nGrimesville, WI 79682      64 Hr       AM
#
#                                                                                          Browser Info  \
# Address
# ...

# %%
purchase.columns
# Out:
# Index(['Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %% [markdown]
# # display top 10 rows of the dataset

# %%
purchase
# Out:
#                                                       Lot AM or PM  \
# Address
# 16629 Pace Camp Apt. 448\nAlexisborough, NE 771...  46 in       PM
# 9374 Jasmine Spurs Suite 508\nSouth John, TN 84...  28 rn       PM
# Unit 0065 Box 5052\nDPO AP 27450                    94 vE       PM
# 7780 Julia Fords\nNew Stacy, WA 45798               36 vm       PM
# 23012 Munoz Drive Suite 337\nNew Cynthia, TX 57826  20 IE       AM
# ...                                                   ...      ...
# 966 Castaneda Locks\nWest Juliafurt, CO 96415       92 XI       PM
# 832 Curtis Dam Suite 785\nNorth Edwardburgh, TX...  41 JY       AM
# Unit 4434 Box 6343\nDPO AE 28026-0283               74 Zh       AM
# 0096 English Rest\nRoystad, IA 12457                74 cL       PM
# 40674 Barrett Stravenue\nGrimesville, WI 79682      64 Hr       AM
#
#                                                                                          Browser Info  \
# Address
# ...

# %%
top = purchase.head(10)

# %%
top
# Out:
#                                                       Lot AM or PM  \
# Address
# 16629 Pace Camp Apt. 448\nAlexisborough, NE 771...  46 in       PM
# 9374 Jasmine Spurs Suite 508\nSouth John, TN 84...  28 rn       PM
# Unit 0065 Box 5052\nDPO AP 27450                    94 vE       PM
# 7780 Julia Fords\nNew Stacy, WA 45798               36 vm       PM
# 23012 Munoz Drive Suite 337\nNew Cynthia, TX 57826  20 IE       AM
# 7502 Powell Mission Apt. 768\nTravisland, VA 30...  21 XT       PM
# 93971 Conway Causeway\nAndersonburgh, AZ 75107      96 Xt       AM
# 260 Rachel Plains Suite 366\nCastroberg, WV 248...  96 pG       PM
# 2129 Dylan Burg\nNew Michelle, ME 28650             45 JN       PM
# 3795 Dawson Extensions\nLake Tinafort, ID 88739     15 Ug       AM
#
#                                                                                          Browser Info  \
# Address
# 16629 Pace Camp Apt. 448\nAlexisborough, NE 771...  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# ...

# %% [markdown]
# # check last row of the data set

# %%
purchase.tail(10)
# Out:
#                                                       Lot AM or PM  \
# Address
# 75731 Molly Springs\nWest Danielle, VT 96934-5102   93 ty       PM
# PSC 8165, Box 8498\nAPO AP 60327-0346               50 dA       AM
# 885 Allen Mountains Apt. 230\nWallhaven, LA 16995   40 vH       PM
# 7555 Larson Locks Suite 229\nEllisburgh, MA 349...  72 jg       PM
# 6276 Rojas Hollow\nLake Louis, WY 56410-7837        93 Ex       PM
# 966 Castaneda Locks\nWest Juliafurt, CO 96415       92 XI       PM
# 832 Curtis Dam Suite 785\nNorth Edwardburgh, TX...  41 JY       AM
# Unit 4434 Box 6343\nDPO AE 28026-0283               74 Zh       AM
# 0096 English Rest\nRoystad, IA 12457                74 cL       PM
# 40674 Barrett Stravenue\nGrimesville, WI 79682      64 Hr       AM
#
#                                                                                          Browser Info  \
# Address
# 75731 Molly Springs\nWest Danielle, VT 96934-5102   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_4;...
# ...

# %% [markdown]
# # check the datatypes of the each  column of the data

# %%
purchase.dtypes
# Out:
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %% [markdown]
# # check the null value

# %%
purchase.isnull().sum()
# Out:
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %% [markdown]
# # how many row and columns of the data set

# %%
len(purchase.columns)
# Out:
# 13

# %%
len(purchase)
# Out:
# 10000

# %%
purchase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 16629 Pace Camp Apt. 448
# Alexisborough, NE 77130-7478 to 40674 Barrett Stravenue
# Grimesville, WI 79682
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Lot               10000 non-null  object
#  1   AM or PM          10000 non-null  object
#  2   Browser Info      10000 non-null  object
#  3   Company           10000 non-null  object
#  4   Credit Card       10000 non-null  int64
#  5   CC Exp Date       10000 non-null  object
#  6   CC Security Code  10000 non-null  int64
#  7   CC Provider       10000 non-null  object
#  8   Email             10000 non-null  object
#  9   Job               10000 non-null  object
#  10  IP Address        10000 non-null  object
#  11  Language          10000 non-null  object
#  12  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 1.1+ MB

# %% [markdown]
# # find the high and lowest purchase value of the data set

# %%
purchase.columns
# Out:
# Index(['Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
purchase['Purchase Price']
# Out:
# Address
# 16629 Pace Camp Apt. 448\nAlexisborough, NE 77130-7478     98.14
# 9374 Jasmine Spurs Suite 508\nSouth John, TN 84355-4179    70.73
# Unit 0065 Box 5052\nDPO AP 27450                            0.95
# 7780 Julia Fords\nNew Stacy, WA 45798                      78.04
# 23012 Munoz Drive Suite 337\nNew Cynthia, TX 57826         77.82
#                                                            ...
# 966 Castaneda Locks\nWest Juliafurt, CO 96415              82.21
# 832 Curtis Dam Suite 785\nNorth Edwardburgh, TX 55158      25.63
# Unit 4434 Box 6343\nDPO AE 28026-0283                      83.98
# 0096 English Rest\nRoystad, IA 12457                       38.84
# 40674 Barrett Stravenue\nGrimesville, WI 79682             67.59
# Name: Purchase Price, Length: 10000, dtype: float64

# %%
purchase['Purchase Price'].max()
# Out:
# 99.99

# %%
purchase['Purchase Price'].min()
# Out:
# 0.0

# %%
purchase.describe()
# Out:
#         Credit Card  CC Security Code  Purchase Price
# count  1.000000e+04      10000.000000    10000.000000
# mean   2.341374e+15        907.217800       50.347302
# std    2.256103e+15       1589.693035       29.015836
# min    6.040186e+10          0.000000        0.000000
# 25%    3.056322e+13        280.000000       25.150000
# 50%    8.699942e+14        548.000000       50.505000
# 75%    4.492298e+15        816.000000       75.770000
# max    6.012000e+15       9993.000000       99.990000

# %% [markdown]
# # average purchase price

# %%
purchase['Purchase Price'].mean()
# Out:
# 50.347302

# %% [markdown]
# # how many people speaking the 'fr' french languge

# %%
purchase
# Out:
#                                                       Lot AM or PM  \
# Address
# 16629 Pace Camp Apt. 448\nAlexisborough, NE 771...  46 in       PM
# 9374 Jasmine Spurs Suite 508\nSouth John, TN 84...  28 rn       PM
# Unit 0065 Box 5052\nDPO AP 27450                    94 vE       PM
# 7780 Julia Fords\nNew Stacy, WA 45798               36 vm       PM
# 23012 Munoz Drive Suite 337\nNew Cynthia, TX 57826  20 IE       AM
# ...                                                   ...      ...
# 966 Castaneda Locks\nWest Juliafurt, CO 96415       92 XI       PM
# 832 Curtis Dam Suite 785\nNorth Edwardburgh, TX...  41 JY       AM
# Unit 4434 Box 6343\nDPO AE 28026-0283               74 Zh       AM
# 0096 English Rest\nRoystad, IA 12457                74 cL       PM
# 40674 Barrett Stravenue\nGrimesville, WI 79682      64 Hr       AM
#
#                                                                                          Browser Info  \
# Address
# ...

# %%
purchase.columns
# Out:
# Index(['Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %% [markdown]
# # first method

# %%
purchase.Language.value_counts()
# Out:
# de    1155
# ru    1155
# el    1137
# pt    1118
# en    1098
# fr    1097
# es    1095
# it    1086
# zh    1059
# Name: Language, dtype: int64

# %% [markdown]
# # second method

# %%
purchase[purchase['Language'] == 'fr']
# Out:
#                                                       Lot AM or PM  \
# Address
# 9374 Jasmine Spurs Suite 508\nSouth John, TN 84...  28 rn       PM
# 125 Hall Summit\nBoothton, IL 41721                 99 CU       PM
# PSC 9431, Box 7059\nAPO AA 29285-1363               14 qD       AM
# 49206 Campbell Port\nNorth Cliffordshire, HI 38945  71 iu       PM
# 493 Smith Valleys Suite 004\nNew Madelineville,...  35 ls       PM
# ...                                                   ...      ...
# 43757 Brown Lodge\nValerieberg, PR 88518            68 DG       AM
# 32827 Carl Inlet\nSouth Nicole, NY 38081-6636       40 Dp       PM
# 518 Brown Dam\nGarciaside, IN 33057                 71 wq       AM
# 02182 Keith Expressway\nEast Shannon, CT 20578-...  34 RL       AM
# 6061 Dave Lights\nPhillipsview, UT 40500            25 Mv       AM
#
#                                                                                          Browser Info  \
# Address
# ...

# %%
len(purchase[purchase['Language'] == 'fr'])
# Out:
# 1097

# %% [markdown]
# # job title contain engineer

# %%
purchase
# Out:
#                                                       Lot AM or PM  \
# Address
# 16629 Pace Camp Apt. 448\nAlexisborough, NE 771...  46 in       PM
# 9374 Jasmine Spurs Suite 508\nSouth John, TN 84...  28 rn       PM
# Unit 0065 Box 5052\nDPO AP 27450                    94 vE       PM
# 7780 Julia Fords\nNew Stacy, WA 45798               36 vm       PM
# 23012 Munoz Drive Suite 337\nNew Cynthia, TX 57826  20 IE       AM
# ...                                                   ...      ...
# 966 Castaneda Locks\nWest Juliafurt, CO 96415       92 XI       PM
# 832 Curtis Dam Suite 785\nNorth Edwardburgh, TX...  41 JY       AM
# Unit 4434 Box 6343\nDPO AE 28026-0283               74 Zh       AM
# 0096 English Rest\nRoystad, IA 12457                74 cL       PM
# 40674 Barrett Stravenue\nGrimesville, WI 79682      64 Hr       AM
#
#                                                                                          Browser Info  \
# Address
# ...

# %%
purchase.columns
# Out:
# Index(['Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
purchase[purchase['Job'] == 'Drilling engineer']
# Out:
#                                                       Lot AM or PM  \
# Address
# 9374 Jasmine Spurs Suite 508\nSouth John, TN 84...  28 rn       PM
# 7780 Julia Fords\nNew Stacy, WA 45798               36 vm       PM
# PSC 9956, Box 2820\nAPO AE 81969-8768               14 yG       PM
# 32038 Adams Valley Suite 436\nNorth Kaylacheste...  44 eL       AM
# 98753 Smith Radial Suite 963\nSouth Jasmine, RI...  45 cj       AM
# PSC 7147, Box 5613\nAPO AE 35453                    76 Cs       AM
# 98274 Henderson Expressway Suite 475\nPort Hayl...  32 Ls       PM
# 01333 Nicholas Hill Suite 739\nEast Maria, DE 9...  45 tj       AM
# 96370 Shannon Isle Apt. 581\nRandallton, PA 621...  05 cD       PM
# 031 Lang Plaza\nLake Matthewchester, NE 79519-5365  13 DM       PM
# 5865 Wendy Square\nNew Jacqueline, SD 40769-9181    02 JU       PM
# PSC 9130, Box 5382\nAPO AP 58279                    36 MU       PM
# 0633 Diane Manors Suite 038\nKristinafort, MA 7...  70 sb       AM
# ...

# %%
len(purchase[purchase['Job'] == 'Drilling engineer'])
# Out:
# 21

# %%
purchase[purchase['Job'].str.contains('engineer')]
# Out:
#                                                       Lot AM or PM  \
# Address
# 9374 Jasmine Spurs Suite 508\nSouth John, TN 84...  28 rn       PM
# 7780 Julia Fords\nNew Stacy, WA 45798               36 vm       PM
# 41159 Michael Centers\nAdamsfort, RI 37108-6674     46 Ce       PM
# 480 Ronald Cape\nJohnville, MA 53644                11 wg       AM
# 1010 Mahoney Mills Suite 486\nWest Danielleview...  70 Fd       AM
# ...                                                   ...      ...
# 52276 Smith Cliffs\nLake Vanessaview, AL 91791      40 nG       AM
# 95544 Johnson Isle Suite 939\nMichaelberg, RI 3...  91 bW       AM
# 0060 Keith Stream\nWestport, CO 47097               11 nt       PM
# 02182 Keith Expressway\nEast Shannon, CT 20578-...  34 RL       AM
# 832 Curtis Dam Suite 785\nNorth Edwardburgh, TX...  41 JY       AM
#
#                                                                                          Browser Info  \
# Address
# ...

# %%
len(purchase[purchase['Job'].str.contains('engineer')])
# Out:
# 531

# %%
len(purchase[purchase['Job'].str.contains('engineer', case = False)])
# Out:
# 984

# %% [markdown]
# # those people using the @yahoo email id

# %%
purchase[purchase['Email'].str.contains('yahoo')]
# Out:
#                                                       Lot AM or PM  \
# Address
# 16629 Pace Camp Apt. 448\nAlexisborough, NE 771...  46 in       PM
# 93971 Conway Causeway\nAndersonburgh, AZ 75107      96 Xt       AM
# 118 Melton Via Suite 681\nAlexanderbury, FL 32104   36 bu       PM
# 8774 Jason Keys Suite 427\nEast Scottborough, M...  70 zH       AM
# 31730 Chelsea Crest\nBlakemouth, CT 90395-0620      41 Cj       PM
# ...                                                   ...      ...
# PSC 8781, Box 4214\nAPO AP 94478                    72 Ez       AM
# 92126 Daniel Streets\nNorth Patricia, IA 10477      04 QN       PM
# 500 Powell Rapid Apt. 114\nClarkfort, FL 70488      48 is       AM
# 02182 Keith Expressway\nEast Shannon, CT 20578-...  34 RL       AM
# 00490 Joseph Haven Apt. 149\nWest Keithfurt, SC...  69 XK       PM
#
#                                                                                          Browser Info  \
# Address
# ...

# %%
len(purchase[purchase['Email'].str.contains('yahoo')])
# Out:
# 1616

# %%
purchase['Email'].str.contains('yahoo').value_counts()
# Out:
# False    8384
# True     1616
# Name: Email, dtype: int64

# %% [markdown]
# # find email of the person whose ip address is 24.140.33.94

# %%
purchase.columns
# Out:
# Index(['Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
purchase['IP Address'] == '24.140.33.94'
# Out:
# Address
# 16629 Pace Camp Apt. 448\nAlexisborough, NE 77130-7478     False
# 9374 Jasmine Spurs Suite 508\nSouth John, TN 84355-4179    False
# Unit 0065 Box 5052\nDPO AP 27450                           False
# 7780 Julia Fords\nNew Stacy, WA 45798                      False
# 23012 Munoz Drive Suite 337\nNew Cynthia, TX 57826          True
#                                                            ...
# 966 Castaneda Locks\nWest Juliafurt, CO 96415              False
# 832 Curtis Dam Suite 785\nNorth Edwardburgh, TX 55158      False
# Unit 4434 Box 6343\nDPO AE 28026-0283                      False
# 0096 English Rest\nRoystad, IA 12457                       False
# 40674 Barrett Stravenue\nGrimesville, WI 79682             False
# Name: IP Address, Length: 10000, dtype: bool

# %%
len(purchase['IP Address'] == '24.140.33.94')
# Out:
# 10000

# %%
purchase[purchase['IP Address'] == '24.140.33.94']
# Out:
#                                                       Lot AM or PM  \
# Address
# 23012 Munoz Drive Suite 337\nNew Cynthia, TX 57826  20 IE       AM
#
#                                                                                          Browser Info  \
# Address
# 23012 Munoz Drive Suite 337\nNew Cynthia, TX 57826  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                                                                       Company  \
# Address
# 23012 Munoz Drive Suite 337\nNew Cynthia, TX 57826  Brown, Watson and Andrews
#
#                                                          Credit Card  \
# Address
# 23012 Munoz Drive Suite 337\nNew Cynthia, TX 57826  6011456623207998
#
#                                                    CC Exp Date  \
# Address
# 23012 Munoz Drive Suite 337\nNew Cynthia, TX 57826       10/25
#
#                                                     CC Security Code  \
# Address
# ...

# %%
purchase[purchase['IP Address'] == '24.140.33.94']['Email']
# Out:
# Address
# 23012 Munoz Drive Suite 337\nNew Cynthia, TX 57826    christopherwright@gmail.com
# Name: Email, dtype: object

# %%
purchase
# Out:
#                                                       Lot AM or PM  \
# Address
# 16629 Pace Camp Apt. 448\nAlexisborough, NE 771...  46 in       PM
# 9374 Jasmine Spurs Suite 508\nSouth John, TN 84...  28 rn       PM
# Unit 0065 Box 5052\nDPO AP 27450                    94 vE       PM
# 7780 Julia Fords\nNew Stacy, WA 45798               36 vm       PM
# 23012 Munoz Drive Suite 337\nNew Cynthia, TX 57826  20 IE       AM
# ...                                                   ...      ...
# 966 Castaneda Locks\nWest Juliafurt, CO 96415       92 XI       PM
# 832 Curtis Dam Suite 785\nNorth Edwardburgh, TX...  41 JY       AM
# Unit 4434 Box 6343\nDPO AE 28026-0283               74 Zh       AM
# 0096 English Rest\nRoystad, IA 12457                74 cL       PM
# 40674 Barrett Stravenue\nGrimesville, WI 79682      64 Hr       AM
#
#                                                                                          Browser Info  \
# Address
# ...

# %%
purchase.columns
# Out:
# Index(['Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %% [markdown]
# # how many people have mastercard as well as creadit card and purchase price is above 50

# %%
purchase[['Credit Card','CC Provider']]
# Out:
#                                                          Credit Card  \
# Address
# 16629 Pace Camp Apt. 448\nAlexisborough, NE 771...  6011929061123406
# 9374 Jasmine Spurs Suite 508\nSouth John, TN 84...  3337758169645356
# Unit 0065 Box 5052\nDPO AP 27450                        675957666125
# 7780 Julia Fords\nNew Stacy, WA 45798               6011578504430710
# 23012 Munoz Drive Suite 337\nNew Cynthia, TX 57826  6011456623207998
# ...                                                              ...
# 966 Castaneda Locks\nWest Juliafurt, CO 96415        342945015358701
# 832 Curtis Dam Suite 785\nNorth Edwardburgh, TX...   210033169205009
# Unit 4434 Box 6343\nDPO AE 28026-0283               6011539787356311
# 0096 English Rest\nRoystad, IA 12457                 180003348082930
# 40674 Barrett Stravenue\nGrimesville, WI 79682      4139972901927273
#
#                                                                     CC Provider
# Address
# ...

# %%
purchase[purchase['CC Provider'] == 'Mastercard']
# Out:
#                                                       Lot AM or PM  \
# Address
# 9374 Jasmine Spurs Suite 508\nSouth John, TN 84...  28 rn       PM
# 461 Christopher Square\nWest Michaelchester, CA...  17 SB       PM
# USNS Alvarado\nFPO AA 27052-1231                    26 Lh       PM
# 93392 Webb Gardens Apt. 220\nLaurabury, AR 9993...  37 om       AM
# 779 Sydney Keys Apt. 119\nAnthonyside, NH 21795...  21 lh       PM
# ...                                                   ...      ...
# 32827 Carl Inlet\nSouth Nicole, NY 38081-6636       40 Dp       PM
# 95544 Johnson Isle Suite 939\nMichaelberg, RI 3...  91 bW       AM
# 051 Samantha Wells Apt. 328\nScottborough, OR 4...  11 vG       AM
# 087 Larson Roads Apt. 587\nRicestad, WI 98077-7330  95 Kw       AM
# 2754 Klein Mission\nJohnsonview, PA 64925-9624      65 Fg       PM
#
#                                                                                          Browser Info  \
# Address
# ...

# %%
len(purchase[purchase['CC Provider'] == 'Mastercard'])
# Out:
# 816

# %%
purchase[(purchase['CC Provider'] == 'Mastercard')  & (purchase['Purchase Price'] > 50)]
# Out:
#                                                       Lot AM or PM  \
# Address
# 9374 Jasmine Spurs Suite 508\nSouth John, TN 84...  28 rn       PM
# 461 Christopher Square\nWest Michaelchester, CA...  17 SB       PM
# USNS Alvarado\nFPO AA 27052-1231                    26 Lh       PM
# 93392 Webb Gardens Apt. 220\nLaurabury, AR 9993...  37 om       AM
# 431 Bowen Lights\nFergusonborough, MH 01362         31 tG       AM
# ...                                                   ...      ...
# 43757 Brown Lodge\nValerieberg, PR 88518            68 DG       AM
# 95544 Johnson Isle Suite 939\nMichaelberg, RI 3...  91 bW       AM
# 051 Samantha Wells Apt. 328\nScottborough, OR 4...  11 vG       AM
# 087 Larson Roads Apt. 587\nRicestad, WI 98077-7330  95 Kw       AM
# 2754 Klein Mission\nJohnsonview, PA 64925-9624      65 Fg       PM
#
#                                                                                          Browser Info  \
# Address
# ...

# %%
len(purchase[(purchase['CC Provider'] == 'Mastercard')  & (purchase['Purchase Price'] > 50)])
# Out:
# 405

# %% [markdown]
# # find the email of the person whose creadit card number is  342945015358701

# %%
purchase
# Out:
#                                                       Lot AM or PM  \
# Address
# 16629 Pace Camp Apt. 448\nAlexisborough, NE 771...  46 in       PM
# 9374 Jasmine Spurs Suite 508\nSouth John, TN 84...  28 rn       PM
# Unit 0065 Box 5052\nDPO AP 27450                    94 vE       PM
# 7780 Julia Fords\nNew Stacy, WA 45798               36 vm       PM
# 23012 Munoz Drive Suite 337\nNew Cynthia, TX 57826  20 IE       AM
# ...                                                   ...      ...
# 966 Castaneda Locks\nWest Juliafurt, CO 96415       92 XI       PM
# 832 Curtis Dam Suite 785\nNorth Edwardburgh, TX...  41 JY       AM
# Unit 4434 Box 6343\nDPO AE 28026-0283               74 Zh       AM
# 0096 English Rest\nRoystad, IA 12457                74 cL       PM
# 40674 Barrett Stravenue\nGrimesville, WI 79682      64 Hr       AM
#
#                                                                                          Browser Info  \
# Address
# ...

# %%
purchase.columns
# Out:
# Index(['Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
purchase['Credit Card'] == 342945015358701
# Out:
# Address
# 16629 Pace Camp Apt. 448\nAlexisborough, NE 77130-7478     False
# 9374 Jasmine Spurs Suite 508\nSouth John, TN 84355-4179    False
# Unit 0065 Box 5052\nDPO AP 27450                           False
# 7780 Julia Fords\nNew Stacy, WA 45798                      False
# 23012 Munoz Drive Suite 337\nNew Cynthia, TX 57826         False
#                                                            ...
# 966 Castaneda Locks\nWest Juliafurt, CO 96415               True
# 832 Curtis Dam Suite 785\nNorth Edwardburgh, TX 55158      False
# Unit 4434 Box 6343\nDPO AE 28026-0283                      False
# 0096 English Rest\nRoystad, IA 12457                       False
# 40674 Barrett Stravenue\nGrimesville, WI 79682             False
# Name: Credit Card, Length: 10000, dtype: bool

# %%
purchase[purchase['Credit Card'] == 342945015358701]['Email']
# Out:
# Address
# 966 Castaneda Locks\nWest Juliafurt, CO 96415    iscott@wade-garner.com
# Name: Email, dtype: object

# %% [markdown]
# # how many people purchase during the Am and pm

# %%
purchase.columns
# Out:
# Index(['Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
purchase['AM or PM'].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %% [markdown]
# # how many have creadit card expire 2020

# %%
purchase
# Out:
#                                                       Lot AM or PM  \
# Address
# 16629 Pace Camp Apt. 448\nAlexisborough, NE 771...  46 in       PM
# 9374 Jasmine Spurs Suite 508\nSouth John, TN 84...  28 rn       PM
# Unit 0065 Box 5052\nDPO AP 27450                    94 vE       PM
# 7780 Julia Fords\nNew Stacy, WA 45798               36 vm       PM
# 23012 Munoz Drive Suite 337\nNew Cynthia, TX 57826  20 IE       AM
# ...                                                   ...      ...
# 966 Castaneda Locks\nWest Juliafurt, CO 96415       92 XI       PM
# 832 Curtis Dam Suite 785\nNorth Edwardburgh, TX...  41 JY       AM
# Unit 4434 Box 6343\nDPO AE 28026-0283               74 Zh       AM
# 0096 English Rest\nRoystad, IA 12457                74 cL       PM
# 40674 Barrett Stravenue\nGrimesville, WI 79682      64 Hr       AM
#
#                                                                                          Browser Info  \
# Address
# ...

# %%
purchase.columns
# Out:
# Index(['Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
purchase['CC Exp Date']
# Out:
# Address
# 16629 Pace Camp Apt. 448\nAlexisborough, NE 77130-7478     02/20
# 9374 Jasmine Spurs Suite 508\nSouth John, TN 84355-4179    11/18
# Unit 0065 Box 5052\nDPO AP 27450                           08/19
# 7780 Julia Fords\nNew Stacy, WA 45798                      02/24
# 23012 Munoz Drive Suite 337\nNew Cynthia, TX 57826         10/25
#                                                            ...
# 966 Castaneda Locks\nWest Juliafurt, CO 96415              03/22
# 832 Curtis Dam Suite 785\nNorth Edwardburgh, TX 55158      07/25
# Unit 4434 Box 6343\nDPO AE 28026-0283                      05/21
# 0096 English Rest\nRoystad, IA 12457                       11/17
# 40674 Barrett Stravenue\nGrimesville, WI 79682             02/19
# Name: CC Exp Date, Length: 10000, dtype: object

# %%
def fun():
    count = 0
    for date in purchase['CC Exp Date']:
        if date.split('/')[1] == '20':
            count = count + 1
        
    print(count)

# %%
fun()
# Out:
# 988

# %%
purchase
# Out:
#                                                       Lot AM or PM  \
# Address
# 16629 Pace Camp Apt. 448\nAlexisborough, NE 771...  46 in       PM
# 9374 Jasmine Spurs Suite 508\nSouth John, TN 84...  28 rn       PM
# Unit 0065 Box 5052\nDPO AP 27450                    94 vE       PM
# 7780 Julia Fords\nNew Stacy, WA 45798               36 vm       PM
# 23012 Munoz Drive Suite 337\nNew Cynthia, TX 57826  20 IE       AM
# ...                                                   ...      ...
# 966 Castaneda Locks\nWest Juliafurt, CO 96415       92 XI       PM
# 832 Curtis Dam Suite 785\nNorth Edwardburgh, TX...  41 JY       AM
# Unit 4434 Box 6343\nDPO AE 28026-0283               74 Zh       AM
# 0096 English Rest\nRoystad, IA 12457                74 cL       PM
# 40674 Barrett Stravenue\nGrimesville, WI 79682      64 Hr       AM
#
#                                                                                          Browser Info  \
# Address
# ...

# %% [markdown]
# # top  most popular email provides as ( @gmail.com, @yahoo.com)

# %%
purchase[purchase['Email'].str.contains('gmail')]
# Out:
#                                                       Lot AM or PM  \
# Address
# 23012 Munoz Drive Suite 337\nNew Cynthia, TX 57826  20 IE       AM
# 7502 Powell Mission Apt. 768\nTravisland, VA 30...  21 XT       PM
# 125 Hall Summit\nBoothton, IL 41721                 99 CU       PM
# 625 Laura Summit Suite 112\nShortmouth, AK 97156    45 oa       PM
# 5334 Sheppard Fort\nNorth Kirsten, ND 71170         40 ND       AM
# ...                                                   ...      ...
# 968 Hannah Common Suite 425\nLake Kaylafort, MH...  72 Yg       PM
# 5419 Cruz Island Apt. 033\nLake Todd, AK 24863-...  93 FM       PM
# 18044 Mcintosh Row Apt. 122\nLake Jennifer, NC ...  77 uq       PM
# 6276 Rojas Hollow\nLake Louis, WY 56410-7837        93 Ex       PM
# Unit 4434 Box 6343\nDPO AE 28026-0283               74 Zh       AM
#
#                                                                                          Browser Info  \
# Address
# ...

# %%
mail = purchase['Email'].value_counts()

# %%
mail
# Out:
# leekathy@yahoo.com           2
# joshua41@hotmail.com         2
# christopher29@gmail.com      2
# ethomas@hotmail.com          2
# brownjohn@hotmail.com        2
#                             ..
# jamesbarnett@gomez.org       1
# hernandezrobert@frank.com    1
# lindseywilliams@pratt.com    1
# ann28@hotmail.com            1
# rachelford@vaughn.com        1
# Name: Email, Length: 9954, dtype: int64

# %%
list1 = []
for item in purchase['Email']:
    list1.append(item.split('@')[1])

# %%
purchase['temp'] = list1

# %%
purchase.head(1)
# Out:
#                                                       Lot AM or PM  \
# Address
# 16629 Pace Camp Apt. 448\nAlexisborough, NE 771...  46 in       PM
#
#                                                                                          Browser Info  \
# Address
# 16629 Pace Camp Apt. 448\nAlexisborough, NE 771...  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
#
#                                                             Company  \
# Address
# 16629 Pace Camp Apt. 448\nAlexisborough, NE 771...  Martinez-Herman
#
#                                                          Credit Card  \
# Address
# 16629 Pace Camp Apt. 448\nAlexisborough, NE 771...  6011929061123406
#
#                                                    CC Exp Date  \
# Address
# 16629 Pace Camp Apt. 448\nAlexisborough, NE 771...       02/20
#
#                                                     CC Security Code  \
# Address
# 16629 Pace Camp Apt. 448\nAlexisborough, NE 771...               900
#
# ...

# %%
purchase['temp'].value_counts()
# Out:
# hotmail.com            1638
# yahoo.com              1616
# gmail.com              1605
# smith.com                42
# williams.com             37
#                        ...
# booker.com                1
# woods-allen.biz           1
# richards-wilson.com       1
# morris-thomas.com         1
# wade-garner.com           1
# Name: temp, Length: 3416, dtype: int64

# %%
purchase['Email']
# Out:
# Address
# 16629 Pace Camp Apt. 448\nAlexisborough, NE 77130-7478                  pdunlap@yahoo.com
# 9374 Jasmine Spurs Suite 508\nSouth John, TN 84355-4179                anthony41@reed.com
# Unit 0065 Box 5052\nDPO AP 27450                           amymiller@morales-harrison.com
# 7780 Julia Fords\nNew Stacy, WA 45798                         brent16@olson-robinson.info
# 23012 Munoz Drive Suite 337\nNew Cynthia, TX 57826            christopherwright@gmail.com
#                                                                         ...
# 966 Castaneda Locks\nWest Juliafurt, CO 96415                      iscott@wade-garner.com
# 832 Curtis Dam Suite 785\nNorth Edwardburgh, TX 55158                  mary85@hotmail.com
# Unit 4434 Box 6343\nDPO AE 28026-0283                                   tyler16@gmail.com
# 0096 English Rest\nRoystad, IA 12457                              elizabethmoore@reid.net
# ...
